# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

class Doublylist:
    def __init__(self):
        self.head = None
    
    
    def insert_at_first(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head = new_node
        
        
    def print_dl(self):
        temp = self.head
        while temp:
            print(temp.data,end=" ")
            temp= temp.next
        
        
    def append(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node
        new_node.prev = last
        
        
    def insert_after(self,data,prev):
        new_node = Node(data)
        if self.head is None:
            print("List must contain at least two nodes!!")
        new_node.next = prev.next
        prev.next = new_node
        new_node.prev = prev
        new_node.next.prev = new_node
        
        
    def delete(self,key):
        temp = self.head
        if temp.data == key:
            self.head = temp.next
            return 
            
        while temp:
            if temp.data == key:
                break;
            prev = temp
            temp = temp.next
        prev.next = temp.next
        temp.next.prev = prev
       
    
    def reverse(self):
        prev = None 
        head = self.head
        while head:
            temp = head
            head = head.next
            temp.next = prev
            prev = temp
        self.head = prev
            
        
        
DL = Doublylist()
DL.insert_at_first(8)
DL.insert_at_first(12)
DL.insert_at_first(4)
DL.insert_at_first(7)
DL.insert_at_first(1)
DL.insert_at_first(66)
DL.append(76)
DL.append(54)
DL.delete(12)
DL.print_dl()
print("\nAfter reverse :")
DL.reverse()
DL.print_dl()
# Out:
# 66 1 7 4 8 76 54
# After reverse :
# 54 76 8 4 7 1 66

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

class DLinkedlist:
    def __init__(self):
        self.head = None
        
        
    def insert_b(self,data):
        new_node  = Node(data)
        if self.head is None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head = new_node
    
    
    def insert_a(self,prev,data):
        new_node = Node(data)
        if prev == None:
            print("the list must contain 2 nodes")
        new_node.next = prev.next
        prev.next = new_node
        new_node.prev = prev
        new_node.next.prev = new_node
        
        
    def append(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node
        new_node.prev = last
    
    
    def print_d(self):
        temp = self.head
        while temp:
            print(temp.data,end=" ")
            temp = temp.next
    
    
    def delete_d(self,key):
        temp = self.head
        if temp.data == key:
            self.head ==temp.next
            return
        while temp:
            if temp.data == key:
                break
            prev = temp
            temp = temp.next
        prev.next = temp.next
        temp.next.prev = prev
         
            
    def reverse(self):
        prev = None
        head = self.head
        while head:
            temp = head
            head = head.next
            temp.next = prev
            prev = temp
        self.head  = prev
    
    
DLL = DLinkedlist()
DLL.append(6)
DLL.append(12)
DLL.append(7)
DLL.append(7)
DLL.append(9)
DLL.append(10)
DLL.append(5)
DLL.append(8)
DLL.print_d()
print("\nafter deleting:")
DLL.delete_d(10)
DLL.print_d()
print("\nAfter reversing: ")
DLL.reverse()
DLL.print_d()
# Out:
# 6 12 7 7 9 10 5 8
# after deleting:
# 6 12 7 7 9 5 8
# After reversing:
# 8 5 9 7 7 12 6
