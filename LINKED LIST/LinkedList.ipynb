# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class SinglyList:
    def __init__(self):
        self.head = None
    
    
    def append(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last = self.head
        while (last.next):
            last = last.next
        last.next = new_node
     
    
    def print_sl(self):
        temp = self.head
        while temp:
            print(temp.data,end=" ")
            temp = temp.next
       
    
    def insert_at_first(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head = new_node
      
    
    def insert_after(self,prev,data):
        new_node = Node(data)
        if prev == None:
            print("SL must contain atleast two nodes")
            return
        new_node.next = prev.next
        prev.next = new_node
        
        
    def delete(self,key):
        temp = self.head
        if temp.data == key:
            temp = self.head.next
            self.head = temp
            return
        while temp:
            if temp.data == key:
                break
            prev = temp
            temp = temp.next
        if temp:
            prev.next = temp.next
        else:
            print("Element Not Found")
    
    
    def reverse(self):
        prev = None
        head = self.head
        while head:
            temp = head
            head = head.next
            temp.next = prev
            prev = temp
        self.head = prev
            
            
    def get_middle(self):
        a = self.head
        b = self.head
        while a and a.next:
            b = b.next
            a = a.next.next
        return b
        print("\n The middle element is:",b.data)
        
        
    def array_to_list(self,array):
        for elements in array:
            self.append(elements)
        
        
    def listtoarray(self):
        array=[]
        temp=self.head
        while temp:
            array.append(temp.data)
            temp = temp.next
        return array
                
                
    def deleteduplicatesort(self):
        temp = self.head
        while temp and temp.next :
            if temp.data == temp.next.data:
                temp.next = temp.next.next
            else:
                temp = temp.next
        
        
    def deleteduplicate(self):
        temp = self.head
        while temp:
            current = temp
            while current.next :
                if current.next.data == temp.data:
                    current.next = current.next.next
                else:
                    current = current.next
            temp = temp.next
                
            
    
    def insert_aftermid(self,data):
        new_node = Node(data)
        node = self.get_middle()
        new_node.next = node.next
        node.next = new_node
         
            
    def search(self,data):
        temp = self.head
        count = 0
        while temp:
            count=count+1
            if temp.data == data:
                return count,temp.data
            temp = temp.next
        
        return -1

# %%
SL= SinglyList()
SL.append(7)
SL.append(10)
SL.append(4)
SL.append(0)
SL.append(0)
SL.append(7)
SL.append(7)
SL.append(11)
SL.append(4)
SL.append(8)
SL.append(0)
SL.insert_at_first(19)
SL.insert_after(SL.head.next,16)
SL.delete(6)
SL.print_sl()
print("\nAfter deleting :")
SL.delete(10)
SL.print_sl()
print("\nAfter reverse:")
SL.reverse()
SL.print_sl()
SL.get_middle()

print("\nafter deleting duplicate elements: ")
# SL.deleteduplicatesort()
SL.deleteduplicate()
SL.print_sl()
print("\n After insertion:")
SL.insert_aftermid(50)
SL.print_sl()
result = SL.search(1)
if result == -1:
    print("\ndata not found")
else:
    print("\nresult:",result)



# print("\n Array to list: ")
# elements=[2,4,1,44,3]
# SL.array_to_list(elements)
# SL.print_sl()

# print("\n List to Array: ")
# toarray = SL.listtoarray()
# print(toarray)
# Out:
# Element Not Found
# 19 7 16 10 4 0 0 7 7 11 4 8 0
# After deleting :
# 19 7 16 4 0 0 7 7 11 4 8 0
# After reverse:
# 0 8 4 11 7 7 0 0 4 16 7 19
# after deleting duplicate elements:
# 0 8 4 11 7 16 19
#  After insertion:
# 0 8 4 11 50 7 16 19
# data not found

# %%
 class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

    
class SS:
    def __init__(self):
        self.head = None
    
    
    def append(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node
        
        
    def print(self):
        temp = self.head
        while temp:
            print(temp.data,end="")
            temp = temp.next
        
        
    def binarydecimal(self):
        decimal=0
        current = self.head
        while current:
            decimal = decimal*2 + current.data
            current = current.next
        return decimal

# %%
S = SS()
S.append(1)
S.append(0)
S.append(1)
S.append(1)
S.print()
print("\nAfter converting binary to decimal:")
result = S.binarydecimal()
print(result)
# Out:
# 1011
# After converting binary to decimal:
# 11

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next= None
    
class SLinkedlist:
    def __init__(self):
        self.head = None
        
    def append_(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node
        
    def printSl_(self):
        temp = self.head
        count = 0
        while temp:
            count = count+1
            print(temp.data)
            temp= temp.next
        print("Number of nodes:",count)  
       
    
    def insert_b(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head = new_node
    
            
    def insert_a(self,prev,data):
        new_node = Node(data)
        if prev == None:
            print("the list must contail atleast two nodes")
            return
        new_node.next = prev.next
        prev.next = new_node
    
    
    def delete_(self,key):
        temp = self.head
        if temp.data == key:
            temp = self.head.next
            self.head = temp
            return 
        while temp:
            if temp.data == key:
                break
            prev = temp
            temp = temp.next
        if temp:
            prev.next = temp.next
        else:
            print("element not found")
            
    
    def reverse_(self):
        prev = None
        head  = self.head
        while head:
            temp = head
            head = head.next
            temp.next = prev
            prev = temp
        self.head = prev
        
        
    def get_middle(self):
        a = self.head
        b = self.head
        while a and a.next:
            a = a.next.next
            b = b.next
        print("\nThe middle element is:",b.data)
        return b
        
       
    def insert_getm(self,data):
        new_node = Node(data)
        node = self.get_middle()
        new_node.next = node.next
        node.next = new_node

    def search_ll(self,key):
        temp = self.head
        count = 0
        while temp:
            count = count+1
            if temp.data == key:
                return temp.data,count 
            temp = temp.next
        return -1
        
        
    def arraylist(self,array):
        for elements in array:
            self.append_(elements)
            
            
    def listarray(self):
        array = []
        temp = self.head
        while temp:
            array.append(temp.data)
            temp = temp.next
        return array
            
        
    def del_dup(self):
        temp = self.head
        while temp:
            current = temp
            while current.next:
                if temp.data == current.next.data:
                    current.next = current.next.next
                else:
                    current = current.next
            temp = temp.next
            
            
            
            
SLL = SLinkedlist()
SLL.append_(23)
SLL.append_(14)
SLL.append_(5)
SLL.append_(9)
SLL.insert_b(10)
SLL.insert_a(SLL.head.next.next,77)
SLL.printSl_()
SLL.delete_(9)
print("\nAfter deletion")
SLL.printSl_()
print("\nAfter Reversing:")
SLL.reverse_()
SLL.printSl_()
SLL.get_middle()
print("\nAfter Inserting:")
SLL.insert_getm(45)
SLL.printSl_()
result = SLL.search_ll(5)
if result == -1:
    print("Element not found")
else:
    print("the result is:",result)
elements=[1,3,2,4,5,34,77]
SLL.arraylist(elements)
SLL.printSl_()
toarray=SLL.listarray()
print("List to array:",toarray)
SLL.del_dup()
print("After del duplicates:")
SLL.printSl_()
print(count)
# Out:
# 10
# 23
# 14
# 77
# 5
# 9
# Number of nodes: 6
#
# After deletion
# 10
# 23
# 14
# 77
# 5
# Number of nodes: 5
#
# After Reversing:
# 5
# 77
# 14
# 23
# 10
# Number of nodes: 5
#
# The middle element is: 14
#
# After Inserting:
#
# The middle element is: 14
# 5
# 77
# 14
# 45
# 23
# 10
# Number of nodes: 6
# the result is: (5, 1)
# 5
# 77
# 14
# 45
# 23
# 10
# 1
# 3
# 2
# 4
# 5
# 34
# 77
# Number of nodes: 13
# List to array: [5, 77, 14, 45, 23, 10, 1, 3, 2, 4, 5, 34, 77]
# After del duplicates:
# 5
# 77
# 14
# 45
# 23
# 10
# 1
# 3
# 2
# 4
# 34
# Number of nodes: 11
# <bound method SLinkedlist.get_count of <__main__.SLinkedlist object at 0x00000178130D8FA0>>

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class SLL:
    def __init__(self):
        self.head = None
        
    def bin_dec(self,head):
        decimal = 0
        temp = self.head
        while temp:
            decimal  = decimal * 2 + temp.data
            temp = temp.next
        return decimal
    
    
sll = SLL()
node1 = Node(1)
node2 = Node(1)
node3 = Node(1)
node4 = Node(0)



node1.next = node2
node2.next = node3
node3.next = node4

sll.head = node1
decimal = sll.bin_dec(sll.head)
print(decimal)
# Out:
# 14
